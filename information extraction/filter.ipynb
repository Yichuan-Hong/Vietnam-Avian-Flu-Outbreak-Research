# %%
import numpy as np
import pandas as pd
import extract_from_vnm_source

# %%
# source: 24h
extract_from_vnm_source.main('24h')
# Out:
# sự kiện:
#
#                 bùng phát cúm gia cầm
#
#
#  trong bối cảnh dịch cúm gia cầm bùng phát thành ổ dịch tại 7 tỉnh (hà nội, quảng ninh, hải dương, nam định, ninh bình, phú yên và long an), lực lượng quản lý thị trường tỉnh lạng sơn đã có văn bản tham mưu cho ban chỉ đạo 389 tỉnh chỉ đạo các lực lượng chức năng tăng cường tập trung triển khai quyết liệt, đồng bộ các giải pháp kiểm soát, phòng, chống bệnh cúm gia cầm lây lan diện rộng
#  ['hà nội', 'lạng sơn', 'quảng ninh', 'hải dương', 'nam định', 'ninh bình', 'phú yên', 'long an', 'hải dương', 'lạng sơn', 'nam định', 'ninh bình', 'hải dương', 'lạng sơn', 'nam định', 'ninh bình', 'quảng ninh']
#
# các nhà khoa học nhận định có mối liên hệ giữa nguyên nhân chết ở chim hoang dã, di cư và các vụ dịch tại các trang trại nuôi gia cầm
#  []
#
# dịch cúm gia cầm áp sát thủ đô hà nội
#
# chủ nhật, ngày 02/03/2014 00:05 am (gmt+7)
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
# source: baohatinh
extract_from_vnm_source.main('baohatinh')
# Out:
# hoạt động ổn định của formosa thúc đẩy dịch vụ kho bãi hỗ trợ vận tải hà tĩnh tăng. cơ cấu kinh tế chuyển dịch theo hướng tích cực, tỷ trọng nông nghiệp còn 12,9%, công nghiệp - xây dựng 45,8%, dịch vụ 41,3%. hoạt động sản xuất chăn nuôi có dấu hiệu tích cực, tuy vậy, các địa phương trong toàn tỉnh vẫn tiếp tục tập trung các biện pháp phòng, chống dịch tả lợn châu phi và các dịch bệnh khác như bệnh viêm da nổi cục ở trâu, bò, dịch cúm gia cầm; tổng sản lượng khai thác và nuôi trồng thủy sản đạt 3. dịch vụ: tổng mức bán lẻ hàng hóa đạt trên 4. ảnh thanh hảinhững kết quả to lớn mà đảng bộ và nhân dân tỉnh ta đạt được trong những năm qua là tiền đề, động lực quan trọng để thực hiện thành công nghị quyết đại hội đảng bộ tỉnh lần thứ xix, nhiệm kỳ 2020-2025, xây dựng hà tĩnh trở thành tỉnh có công nghiệp, nông nghiệp, dịch vụ phát triển, hệ thống kết cấu hạ tầng đồng bộ; đến năm 2025 tỉnh đạt chuẩn ntm, thu nhập bình quân đầu người cao hơn bình quân các tỉnh bắc trung bộ, phấn đấu năm 203
# ...

# %%
# source: baonghean
extract_from_vnm_source.main('baonghean')
# Out:
# theo báo cáo của cơ quan chức năng tỉnh nghệ an, sau tết nguyên đán vừa qua, dịch tả lợn châu phi đã tái bùng phát rải rác ở một số hộ chăn nuôi tại các huyện nghi lộc, yên thành, thanh chương, nam đàn, hưng nguyên, diễn châu, quỳnh lưu, đô lương và con cuông. a
# hiện trên địa bàn tỉnh còn 5 ổ dịch chưa qua 21 ngày, bao gồm: xã ngọc lâm (thanh chương), xã xuân sơn (đô lương), xã mậu đức, môn sơn (con cuông). a
# ...

# %%
# source: baoquangninh
extract_from_vnm_source.main('baoquangninh')
# Out:
# ngay sau đó, trung tâm dịch vụ kỹ thuật nông nghiệp tp hạ long đã lấy mẫu gửi đi xét nghiệm và có kết quả như trên. được biết, hiện các đơn vị chức năng đang khẩn trương triển khai các biện pháp khoanh vùng, dập dịch tại ổ dịch thôn bãi cát, xã vũ oai, tp hạ long; đồng thời quyết liệt ngăn chặn nguy cơ lây lan dịch
#  ['hạ long', 'hạ long']
#
# "who, thông qua hệ thống giám sát và ứng phó cúm toàn cầu (gisrs) liên tục theo dõi các virus cúm, bao gồm cả những virus có khả năng gây đại dịch và tiến hành đánh giá nguy cơ
#  []
#
# ...

# %%
# source: baothanhhoa
extract_from_vnm_source.main('baothanhhoa')
# Out:
# từ đầu năm đến nay, dịch bệnh covid-19 đã khiến cho việc sản xuất nông nghiệp trên địa bàn tỉnh có phần xáo trộn, việc tiêu thụ nông sản ít nhiều cũng đang bị ảnh hưởng. dự báo, tình hình dịch bệnh sẽ còn tiếp tục diễn biến phức tạp, ảnh hưởng đến việc sản xuất, tiêu thụ nông sản trên địa bàn tỉnh. trên cơ sở đánh giá tình hình thực tế, dự báo những khó khăn phải đối mặt trong thời gian tới do ảnh hưởng của các loại dịch bệnh và biến động của thị trường, sở nông nghiệp và phát triển nông thôn đã chủ động xây dựng và triển khai thực hiện các nhóm giải pháp nhằm tháo gỡ khó khăn trong sản xuất, tiêu thụ nông sản, từ đó tiếp tục đẩy mạnh phát triển nông nghiệp
#  []
#
# ...

# %%
# source: doisong
extract_from_vnm_source.main('doisong')
# Out:
# trước đó, trưa ngày 24/3, tài khoản facebook mang tên trần thu hồng (trú tại thị xã gia nghĩa, tỉnh đắk nông) đăng tải nội dung thông tin và hình ảnh lợn dịch tại huyện đăk mil, tỉnh đăk nông mang đi tiêu hủy bị gian thương đào lên, mổ bán. người quen làm bên kiểm dịch mới bắt ổ dịch ở đăk min hơn 800 con chôn rồi mà bọn gian thương đào lên mổ xẻ để bán đấy. hình ảnh heo chết được chủ nhân trang facebook sử dụngtuy nhiên, theo thông tin trên vov, ông ngô thanh hải, phó chủ tịch ubnd huyện đắk mil, tỉnh đắk nông khẳng định, trên địa bàn không xuất hiện ổ lợn dịch nào như thông tin mà chủ facebook trên đăng tải. đồng thời, chủ nhân bài viết đã đăng thông tin đính chính, rằng ở đắk nông chưa có ổ dịch lợn nào
#  ['đắk nông', 'gia nghĩa', 'đắk mil', 'gia nghĩa']
#
# ...

# %%
# source: kenh14
extract_from_vnm_source.main('kenh14')
# Out:
# trung tâm dịch vụ kỹ thuật nông nghiệp thành phố hạ long đã lấy 3 mẫu xét nghiệm cho kết quả dương tính với virus cúm gia cầm a/h5n8
#  ['hạ long', 'hạ long']
#
# trong bối cảnh dịch cúm gia cầm bùng phát thành ổ dịch tại 7 tỉnh (hà nội, quảng ninh, hải dương, nam định, ninh bình, phú yên và long an), lực lượng quản lý thị trường tỉnh lạng sơn đã có văn bản tham mưu cho ban chỉ đạo 389 tỉnh chỉ đạo các lực lượng chức năng tăng cường tập trung triển khai quyết liệt, đồng bộ các giải pháp kiểm soát, phòng, chống bệnh cúm gia cầm lây lan diện rộng
#  ['hà nội', 'lạng sơn', 'quảng ninh', 'hải dương', 'nam định', 'ninh bình', 'phú yên', 'long an', 'hải dương', 'lạng sơn', 'nam định', 'ninh bình', 'hải dương', 'lạng sơn', 'nam định', 'ninh bình', 'quảng ninh']
#
# cuối tháng 11 vừa qua, hàn quốc thông báo bùng phát cúm gia cầm độc lực cao tại nước này lần đầu tiên trong vòng 32 tháng
#  []
#
# ...

# %%
# source: nongnghiep
extract_from_vnm_source.main('nongnghiep')
# Out:
# ngay sau đó, trung tâm dịch vụ kỹ thuật nông nghiệp tp hạ long đã lấy mẫu gửi đi xét nghiệm và có kết quả dương tính với virus cúm gia cầm a/h5n8. hiện các đơn vị chức năng đang khẩn trương triển khai các biện pháp khoanh vùng, dập dịch tại ổ dịch thôn bãi cát, xã vũ oai, tp hạ long, đồng thời quyết liệt ngăn chặn nguy cơ lây lan dịch
#  ['hạ long', 'hạ long']
#
# hơn 330 vụ bùng phát có mầm bệnh cao đã được các quan chức thú y của đất nước ghi nhận
#  []
#
# ...

# %%
# source: sggp
extract_from_vnm_source.main('sggp')
# Out:
# đây là dự án hợp tác giữa cục thú y, sở nn-ptnt tỉnh bình phước, công ty tnhh cpv food nhằm thiết lập vùng an toàn dịch bệnh cúm gia cầm; xuất khẩu thịt gia cầm sang châu âu và các nước nhật bản, hàn quốc, singapore…
#
# dự án có nhà máy thức ăn công suất 0,3 triệu tấn/năm, 5 trại gà giống cha mẹ (0,5 triệu con/năm), 24 trại gà thịt (52 triệu con/năm), 1 nhà máy ấp trứng (53,6 triệu con/năm), 1 nhà máy giết mổ 116
#  ['bình phước']
#
# nhiều người dân buôn bán gia cầm sống trên đường nguyễn văn công (quận gò vấp)
#
# cấm vẫn bán
#
# từ nhiều năm qua, để phòng ngừa dịch cúm gia cầm, tphcm đã chỉ đạo cấm mọi hoạt động vận chuyển, kinh doanh gia cầm sống
#  ['gò vấp', 'gò vấp', 'gò vấp']
#
# thủ tướng nguyễn xuân phúc chủ trì hội nghị
# báo cáo tại hội nghị này, bộ trưởng bộ nn-ptnt nguyễn xuân cường khẳng định, năm 2020, ngành nông nghiệp việt nam đã phải trải qua một năm chồng chất khó khăn, phải vượt qua 4 thách thức:
# ...

# %%
# source: thanhnien
extract_from_vnm_source.main('thanhnien')
# Out:
# buôn ma thuột (đắk lắk) ban hành quyết định công bố dịch cúm gia cầm trên địa bàn thành phố. trong đó, vùng có dịch tại xã ea kao; vùng dịch bị uy hiếp gồm: xã hòa khánh, xã hòa thắng và p. buôn ma thuột giao ban chỉ đạo phòng chống dịch bệnh động vật trên cạn của thành phố cùng các đơn vị chức năng, các xã, phường trên thực hiện quyết liệt các biện pháp phòng, chống dịch cúm gia cầm thể độc lực cao, không để lây lan
#  ['đắk lắk', 'buôn ma thuột', 'buôn ma thuột', 'lắk']
#
# ...

# %%
# source: tuoitre
extract_from_vnm_source.main('tuoitre')
# Out:
# ngay sau đó, trung tâm dịch vụ kỹ thuật nông nghiệp tp hạ long đã tổ chức lấy mẫu gửi đi xét nghiệm và có kết quả như trên. hiện các đơn vị chức năng của quảng ninh đang khẩn trương triển khai các biện pháp khoanh vùng, dập dịch tại ổ dịch thôn bãi cát, xã vũ oai, tp hạ long, đồng thời quyết liệt ngăn chặn nguy cơ lây lan dịch
#  ['quảng ninh', 'hạ long', 'quảng ninh', 'hạ long']
#
# giới chức nhật bản cam kết hỗ trợ chính quyền tỉnh shiba ứng phó với đợt dịch bùng phát này. tiêu hủy gia cầm ở trang trại có nhiễm tại mihara, tỉnh hiroshima (nhật) - ảnh: reuterstrong khi đó, tình hình dịch cúm gia cầm tại hàn quốc vẫn ở mức đáng báo động khi số ca nhiễm cúm gia cầm độc lực cao ở nước này tiếp tục tăng lên, nâng tổng số ca nhiễm virus cúm gia cầm tại các trang trại trên cả nước lên con số 12 tính từ cuối tháng 11
#  []
#
# ...

# %%
# source: vietnamnet
extract_from_vnm_source.main('vietnamnet')
# Out:
# trung quốc vừa phát hiện sự bùng phát của cúm gia cầm h5n1 (cúm a/h5n1) cực nguy hiểm ở tỉnh hồ nam, giáp phía nam tỉnh hồ bắc, tâm chấn của dịch virus corona mới (2019-ncov hay virus vũ hán) đang gây rúng động toàn thế giới. số ca nhiễm virus corona tăng vọt, 304 người chếtdùng robot đưa thức ăn cho người bị cách ly vì virus vũ hánthực hư 'ác mộng' thiếu hụt khẩu trang ở ổ dịch virus corona  "cúm a/h5n1 bùng phát ở một trang trại thuộc quận shuangqing, thành phố thiệu dương, tỉnh hồ nam. 828 con gia cầm sau khi dịch bùng phát", trích tuyên bố ngày 1/2 của bộ nông nghiệp và các vấn đề nông thôn trung quốc. việc bùng phát cúm a/h5n1 ở tỉnh giáp ranh "ổ dịch" virus vũ hán xảy ra đúng vào lúc chính phủ trung quốc đang vật lộn kiểm soát và ngăn chặn sự lây lan của dịch do chủng virus corona mới gây ra
#  []
#
# ...

# %%
# source: zingnews
extract_from_vnm_source.main('zingnews')
# Out:
# chủng cúm mới lần đầu tiên xuất hiện tại việt nam trao đổi với zing, ông trần xuân đông, chi cục trưởng chi cục chăn nuôi và thú y tỉnh quảng ninh, cho biết ổ dịch tại xã vũ oai, tp hạ long là ổ dịch cúm a/h5n8 trên gia cầm đầu tiên được ghi nhận tại việt nam. ngay sau khi có hiện tượng gà chết, ubnd xã báo cáo thành phố và cùng trung tâm dịch vụ kỹ thuật nông nghiệp hạ long đến nhà hộ dân để kiểm tra, lấy mẫu
#  ['quảng ninh', 'hạ long', 'quảng ninh', 'hạ long']
#
# ngay sau đó, trung tâm dịch vụ kỹ thuật nông nghiệp tp hạ long đã lấy mẫu gửi đi xét nghiệm và có kết quả như trên. được biết, hiện các đơn vị chức năng đang khẩn trương triển khai các biện pháp khoanh vùng, dập dịch tại ổ dịch thôn bãi cát, xã vũ oai, tp hạ long; đồng thời quyết liệt ngăn chặn nguy cơ lây lan dịch
#  ['hạ long', 'hạ long']
#
# nhờ chuyển đổi số các dịch vụ, sinh viên được trải nghiệm công nghệ tiện ích và tiếp cận những kỹ năng, xu hướng của tương lai
#  []
#
# ...
